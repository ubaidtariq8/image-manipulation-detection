# %%
from inference_demo import run

IMAGE_SOURCE = "demo.jpg"
THRESHOLD = 0.5

# %%
run(IMAGE_SOURCE, threshold=THRESHOLD)
# Out:
# Classification: manipulated
# Manipulation probability: 0.6587
# Threshold: 0.50
# {'classification_probability': 0.65869140625,
#  'threshold': 0.5,
#  'predicted_label': 1,
#  'mask_positive_ratio': 0.021189371744791668}
